# %% [markdown]
# # Learning ArcGIS
#
# This is my first experience with ArcGIS API using python.
#
# First we import necessary packages and log into the

# %%
import arcgis
import getpass
from arcgis import GIS

password = getpass.getpass('Enter password')
gis = GIS('https://www.arcgis.com', 'csouflis', password)

print('Successfully logged in as: ' + gis.properties.user.username)
# Out:
# Enter password········
# Successfully logged in as: csouflis

# %%
user = gis.users.get('csouflis')
print ('Hello ' + user.firstName + '!')
# Out:
# Hello Chris!

# %%
from IPython.display import display
items = gis.content.search('new york city', max_items=10)
for item in items:
    display(item)
# Out:
# <Item title:"Ocean Basemap" type:Web Map owner:esri>
# <Item title:"NY Rising Buyouts in Staten Island" type:Web Mapping Application owner:ALentz_GOSR>
# <Item title:"NYC OEM Hurricane Evacuation Zones" type:Web Map owner:nfurness>
# <Item title:"Ghostbusters: Something Strange In Your Neighborhood" type:Web Mapping Application owner:mgallant83>
# <Item title:"North American Pipeline and Oil & Gas Infrastructure Proposals" type:Web Map owner:waauch>
# <Item title:"New York City" type:Web Map owner:user_community>
# <Item title:"1923 United States Map" type:Web Map owner:NationalGeographic>
# <Item title:"Urban Observatory Compare App" type:Web Mapping Application owner:AtlasPublisher>
# <Item title:"New York City: Place Matters" type:Web Mapping Application owner:StoryMaps>
# <Item title:"Ring in 2014" type:Web Mapping Application owner:robe6923>

# %%
map1 = gis.map('New York, NY')
map1
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-b4710b6d-3717-485f-8adf-9215d36c7660"><img src=""></img></div>

# %%
map1.basemaps
# Out:
# ['dark-gray',
#  'dark-gray-vector',
#  'gray',
#  'gray-vector',
#  'hybrid',
#  'national-geographic',
#  'oceans',
#  'osm',
#  'satellite',
#  'streets',
#  'streets-navigation-vector',
#  'streets-night-vector',
#  'streets-relief-vector',
#  'streets-vector',
#  'terrain',
#  'topo',
#  'topo-vector']

# %%
map1.basemap = 'satellite'

# %%
map.zoom =19
# Out:
# ['dark-gray',
#  'dark-gray-vector',
#  'gray',
#  'gray-vector',
#  'hybrid',
#  'national-geographic',
#  'oceans',
#  'osm',
#  'satellite',
#  'streets',
#  'streets-navigation-vector',
#  'streets-night-vector',
#  'streets-relief-vector',
#  'streets-vector',
#  'terrain',
#  'topo',
#  'topo-vector']

# %%
single_line_address = '20 W 34th St, New York, NY 10001'
from arcgis.geocoding import geocode

# %%
empire_state_built = geocode(single_line_address)[0]
popup = {
    "title" : "Empire State Building",
    "content" : empire_state_built['address']
}

# %%
map1.draw(empire_state_built['location'], popup)
map1.extent = empire_state_built['extent']
